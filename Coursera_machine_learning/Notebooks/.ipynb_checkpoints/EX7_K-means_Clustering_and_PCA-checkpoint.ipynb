# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from scipy.io import loadmat
import itertools

# %% [markdown]
# # K-Means Clustering

# %%
data = loadmat('../Data/ex7data2.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X'])

# %%
X = data['X']

# %%
X.shape
# Out:
# (300, 2)

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %% [markdown]
# This problem is way less clear about what datasets to use for what problems. However, this looks like the same data as in figure 1, so I'll stick with it for the K-means clustering.
#
# As usual I'm going to try building some things from scratch before ferreting out the standard implementation. There are 4 basic funcions needed.
# 1. Random initialization of centroids
# 2. Finding the closest centroid to each point
# 3. Calculating the centroid position as the mean of each point in the cluster.

# %%
def randomCentroidInit(X,K):
    permInd = np.random.permutation(X.shape[0])
    return X[permInd[:K],:]

# %%
#My stupid manual kernel implementation from last time is paying off!
def nearestCentroid(X,centroids):
    tmpX = X.reshape(1,X.shape[0],X.shape[1])
    tmpCent = centroids.reshape(centroids.shape[0],1,centroids.shape[1])
    distMat = np.dot((tmpX - tmpCent)**2,np.ones(X.shape[1]))
    return distMat.argmin(0)

# %%
centroids = randomCentroidInit(X,3)

# %%
classes = nearestCentroid(X,centroids)

# %%
fig = plt.figure(figsize = [8,8])
ax = plt.axes(facecolor = [.35, .35, .35])
plt.scatter(X[:,0],X[:,1],c=classes,marker='.')
plt.scatter(centroids[:,0],centroids[:,1],s=100,c=range(3),alpha=.7,cmap = plt.get_cmap('inferno_r'))
plt.show()

# %% [markdown]
# So it works. It should be obvious that the centroids are a different color than their assigned cluster, which is for clarity. As it happens, it appears my random initialization has captured the three clusters pretty well. Of course, there's still some improvement to do. And that's why I need a function to recalculate the centroids.

# %%
def recalculateCentroids(X,K,classes):
    centroids = np.zeros((K,X.shape[1]))
    for k in range(K):
        centroids[k,:] = X[(classes==k),:].mean(axis=0)
    return centroids

# %%
new_cent = recalculateCentroids(X,3,classes)

# %%
new_cent
# Out:
# array([[1.98363152, 5.03043004],
#        [3.06584667, 1.05078048],
#        [6.08335155, 2.97769582]])

# %%
centroids
# Out:
# array([[2.15460139, 5.46282959],
#        [3.45186351, 0.42784083],
#        [6.77012767, 3.21411422]])

# %% [markdown]
# As expected, the new centroid isn't very far from the one I started with, which is a good sign that I did it right.

# %%
fig = plt.figure(figsize = [8,8])
ax = plt.axes(facecolor = [.35, .35, .35])
plt.scatter(X[:,0],X[:,1],c=classes,marker='.')
plt.scatter(centroids[:,0],centroids[:,1],s=100,c='w',label='old')
plt.scatter(new_cent[:,0],new_cent[:,1],s=100,c='k',label='new')
plt.quiver(centroids[:,0],centroids[:,1],new_cent[:,0]-centroids[:,0],new_cent[:,1]-centroids[:,1],\
           color='r',angles='xy',scale=1, scale_units='xy',\
           units='xy',width=.05,headwidth=3,headlength=4,headaxislength=4)
plt.legend()
plt.show()

# %% [markdown]
# Yup, the adjustment was correct!
#
# Last thing is to define a cost function so I can judge which of several random initializations results in the lowest error after many iterations.

# %%
def kMeansCost(X,centroids,classes):
    m, K, N = (X.shape[0], centroids.shape[0], X.shape[1])
    J = 0
    for k in range(K):
        J += np.sum((X[(classes==k),:] - centroids[k,:].reshape(1,N))**2)
    return J/m

# %%
kMeansCost(X,centroids,classes)
# Out:
# 1.3280338824304108

# %%
kMeansCost(X,new_cent,classes)
# Out:
# 0.8999299417177345

# %% [markdown]
# Looks like it works to me. And moving the centroid lowers the cost, which is how it should work. Now to run a few random initializations to see what minimizes the cost.

# %%
rounds = 100
iterations = 10
K=3
cent_list, class_list = ([] for _ in range(2))
J_list = np.zeros((rounds,iterations))
for r in range(rounds):
    cent_list.append([])
    class_list.append([])
    cent_list[r].append(randomCentroidInit(X,K))
    for i in range(iterations):
        class_list[r].append(nearestCentroid(X,cent_list[r][i]))
        cent_list[r].append(recalculateCentroids(X=X,K=K,classes=class_list[r][i]))
        J_list[r,i] = kMeansCost(X=X,centroids=cent_list[r][i+1],classes=class_list[r][i])

# %%
plt.figure(figsize = [20,2])
plt.imshow(J_list.T, origin='lower')
plt.ylabel('Iterations')
plt.xlabel('Initializations')
plt.title('Cost')
plt.colorbar()
plt.show()

# %% [markdown]
# So for the most part, it converges really quick. Let's pick the best one and see what it did. Also, I answered a question I had, which was: Why not just pick the initialization with the _initial_ lowest cost. But this figure shows initializations that started with high cost and still converged to the same answer as the other good ones.

# %%
round_min = J_list[:,-1].argmin()

# %%
classes = class_list[round_min][-1]
fig = plt.figure(figsize = [12,12])
ax = plt.axes(facecolor = [.37, .37, .37])
plt.scatter(X[:,0],X[:,1],c=classes,marker='.')
for k in range(K):
    centroids = np.vstack([cent_list[round_min][i][k,:] for i in range(iterations+1)])
    plt.scatter(centroids[:,0],centroids[:,1],s=50,c='w')
    plt.quiver(centroids[:-1,0],centroids[:-1,1],centroids[1:,0]-centroids[:-1,0],centroids[1:,1]-centroids[:-1,1],\
           color='r',angles='xy',scale=1, scale_units='xy',\
           units='xy',width=.02,headwidth=5,headlength=6,headaxislength=6)
plt.show()

# %% [markdown]
# ## K-means for image coloring

# %%
import png

# %%
f = open('../Data/bird_small.png','rb')
data = png.Reader(file = f).asDirect()
tmp = list(map(np.uint8,data[2]))

# %%
# %%timeit
R = np.vstack([np.vstack([tmp[i][j] for j in range(0,len(tmp[i]),3)]) for i in range(len(tmp))]).reshape(data[0],data[1],1)
G = np.vstack([np.vstack([tmp[i][j] for j in range(1,len(tmp[i]),3)]) for i in range(len(tmp))]).reshape(data[0],data[1],1)
B = np.vstack([np.vstack([tmp[i][j] for j in range(2,len(tmp[i]),3)]) for i in range(len(tmp))]).reshape(data[0],data[1],1)
img = np.concatenate((R,G,B),axis=2)
# Out:
# 114 ms ± 5.03 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
img = np.zeros((data[0],data[1],3),dtype=np.uint8)
for i in range(data[0]):
    for j in range(data[1]):
        for k in range(3):
            img[i,j,k] = tmp[i][j*3+k]
# Out:
# 29.3 ms ± 3.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# I'm not sure if there is a better way to import the image. I had to go find PyPNG and install it. I already had LibPNG installed, but that documentation was 8 years old. At least PyPNG is only 3 years old... And even after I imported the image, I'm not sure if there's a better way to assign it to a matrix. I've at least found the best of two options.
#
# Now to reshape the array in order to perform clustering on it. We want an (m, 3) shaped array for the 3 colors. The goal is to find the centroid of 16 clusters of color.

# %%
X = np.hstack([img[:,:,i].reshape(-1,1) for i in range(3)])
K = 16

# %%
rounds = 100
iterations = 10
cent_list, class_list = ([] for _ in range(2))
J_list = np.zeros((rounds,iterations))
for r in range(rounds):
    cent_list.append([])
    class_list.append([])
    cent_list[r].append(randomCentroidInit(X,K))
    for i in range(iterations):
        class_list[r].append(nearestCentroid(X,cent_list[r][i]))
        cent_list[r].append(recalculateCentroids(X=X,K=K,classes=class_list[r][i]))
        J_list[r,i] = kMeansCost(X=X,centroids=cent_list[r][i+1],classes=class_list[r][i])
# Out:
# C:\Users\joshu\Anaconda3\envs\Python37\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice.
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize = [20,2])
plt.imshow(J_list.T, origin='lower',vmax=1000)
plt.ylabel('Iterations')
plt.xlabel('Initializations')
plt.title('Cost')
plt.colorbar()
plt.show()

# %% [markdown]
# Looks like there are some very bad initializations. It also looks like 10 iterations isn't enough, but most rounds seem to be convering to the same value, so I'll take the closest one and run it through more iterations.

# %%
round_min = J_list[:,-1].argmin()

# %%
iterations = 100
centroids = cent_list[round_min][-1]
J_list = []
for i in range(iterations):
    classes = nearestCentroid(X,centroids)
    centroids = recalculateCentroids(X=X,K=K,classes=classes)
    J_list.append(kMeansCost(X=X,centroids=centroids,classes=classes))

# %%
plt.plot(J_list)
plt.show()

# %% [markdown]
# And it didn't take much longer to hit the global min.
#
# Now to see what the image looks like with new colors.

# %%
squareClasses = np.reshape(classes,(128,128))
roundCent = np.uint8(np.around(centroids))

# %%
compImg = np.zeros((data[0],data[1],3),dtype=np.uint8)
for i in range(data[0]):
    for j in range(data[1]):
        compImg[i,j,:] = roundCent[squareClasses[i,j],:].reshape(1,1,3)

# %%
fix, ax = plt.subplots(1,2, figsize = [12, 6])
ax[0].imshow(img)
ax[0].set_title('Original Image')
ax[0].set_yticks([])
ax[0].set_xticks([])
ax[1].imshow(compImg)
ax[1].set_title('Compressed Image (16 colors)')
ax[1].set_yticks([])
ax[1].set_xticks([])
plt.show()

# %% [markdown]
# That doesn't look too bad. I never thought about clustering colors this way to preserve the integrity of specific images while compressing their information.
#
# Now for the part where I find the standard implementation and apply it, rather than my homemade functions.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=16)
kmeans.fit(X)
skClasses = kmeans.labels_

# %%
skCentroids = kmeans.cluster_centers_

# %%
skSquareClasses = np.reshape(skClasses,(128,128))
skRoundCent = np.uint8(np.around(skCentroids))

# %%
skCompImg = np.zeros((data[0],data[1],3),dtype=np.uint8)
for i in range(data[0]):
    for j in range(data[1]):
        skCompImg[i,j,:] = skRoundCent[skSquareClasses[i,j],:].reshape(1,1,3)

# %%
fix, ax = plt.subplots(1,2, figsize = [12, 6])
ax[0].imshow(compImg)
ax[0].set_title('Compressed Image (my implementation)')
ax[0].set_yticks([])
ax[0].set_xticks([])
ax[1].imshow(skCompImg)
ax[1].set_title('Compressed Image (sklearn implementation)')
ax[1].set_yticks([])
ax[1].set_xticks([])
plt.show()

# %%
(skCompImg==compImg).all()
# Out:
# False

# %% [markdown]
# So they are not perfectly identical, which is interesting since it seems like the clusters should converge to a global minimum, but maybe that is just barely out of reach of the tolerance of the sklearn implementation. Also the sklearn implementation only tries 10 different initializations, while I tried 100, so maybe I just found a better one and forced it to converge all the way, while sklearn found one that was good enough. Regardless, sklearn, as usual, was **way** faster, so of course that's what I'll use.

# %% [markdown]
# # Principle Component Analysis
# Starting with a toy data set, 2D -> 1D.

# %%
data = loadmat('../Data/ex7data1.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X'])

# %%
X = data['X']

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
import numpy.linalg as la
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(X)
scaleX = scaler.transform(X)
m = X.shape[0]
n = X.shape[1]

# %%
Sigma = scaleX.T@scaleX/m

# %%
u,s,_ = la.svd(Sigma)

# %%
k=1
uReduce = u[:,:k]

# %%
z = scaleX@uReduce

# %%
xApprox = np.linspace(z.min(),z.max(),2).reshape(-1,1)@uReduce.T
plt.scatter(scaleX[:,0],scaleX[:,1],label='data')
plt.plot(xApprox[:,0],xApprox[:,1],label='reduced',c='r')
plt.legend()
plt.title('Dimentionality Reduction')
plt.show()

# %%
print(f'{100*np.sum(s[:k])/np.sum(s):.3}% of the variance is retained.')
# Out:
# 86.8% of the variance is retained.

# %% [markdown]
# It looks like there isn't much complexity to this, since it all comes down to the SVD function. But when I'm done I'll research if there are other methods commonly used in python for this technique.
#
# Onto the face image dataset!

# %%
data = loadmat('../Data/ex7faces.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X'])

# %% [markdown]
# X is a matrix where the rows correspond to the pixels in a greyscale image of a face.

# %%
X = data['X']
X.shape
# Out:
# (5000, 1024)

# %%
fig, ax = plt.subplots(figsize=[8,8],nrows=5,ncols=5)
ax = ax.ravel()
for i in range(25):
    ax[i].imshow(X[i,:].reshape(32,32).T,cmap = plt.get_cmap('Greys_r'))
    ax[i].set_yticks([])
    ax[i].set_xticks([])
fig.subplots_adjust(hspace=0,wspace=0)
fig.suptitle('The first 25 faces')
plt.show()

# %% [markdown]
# Indeed, faces.

# %%
scaler = StandardScaler().fit(X)
scaleX = scaler.transform(X)
m = X.shape[0]
n = X.shape[1]
Sigma = scaleX.T@scaleX/m
u,s,_ = la.svd(Sigma)
k=100
uReduce = u[:,:k]
z = scaleX@uReduce

# %%
fig, ax = plt.subplots(figsize=[8,8],nrows=5,ncols=5)
ax = ax.ravel()
for i in range(25):
    ax[i].imshow(uReduce[:,i].reshape(32,32).T,cmap = plt.get_cmap('Greys_r'))
    ax[i].set_yticks([])
    ax[i].set_xticks([])
fig.subplots_adjust(hspace=0,wspace=0)
fig.suptitle('The first 25 EIGENfaces')
plt.show()

# %%
fig, ax = plt.subplots(figsize=[8,8],nrows=5,ncols=5)
ax = ax.ravel()
for i in range(25):
    ax[i].imshow((z@uReduce.T)[i,:].reshape(32,32).T,cmap = plt.get_cmap('Greys_r'))
    ax[i].set_yticks([])
    ax[i].set_xticks([])
fig.subplots_adjust(hspace=0,wspace=0)
fig.suptitle('The first 25 approximated faces')
plt.show()

# %% [markdown]
# It looks like the first 3 eigenfaces caputred most of the shapes required to make a face, so I want to see what that looks like.

# %%
uReduce = u[:,:3]
z = scaleX@uReduce
fig, ax = plt.subplots(figsize=[8,8],nrows=5,ncols=5)
ax = ax.ravel()
for i in range(25):
    ax[i].imshow((z@uReduce.T)[i,:].reshape(32,32).T,cmap = plt.get_cmap('Greys_r'))
    ax[i].set_yticks([])
    ax[i].set_xticks([])
fig.subplots_adjust(hspace=0,wspace=0)
fig.suptitle('The first 25 approximated faces')
plt.show()

# %% [markdown]
# While rather haunting, these are mostly recognizable as faces.
#
# PCA was really cool. It's the kind of thing I might be guilty of applying too liberally in the future because it's so neat and easy. I'll have to read more to find what kinds of problems that it shouldn't be used with. As the lecture said, if you can solve your problem with all the data, then you should use all the data. It might just be that algorithms and computers are so powerful now that PCA is almost never worth it.
