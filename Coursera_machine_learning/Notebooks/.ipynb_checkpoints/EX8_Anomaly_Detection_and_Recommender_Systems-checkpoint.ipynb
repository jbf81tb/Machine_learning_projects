# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from scipy.io import loadmat
from numpy import linalg as la

# %% [markdown]
# # Anomaly Detection

# %%
data = loadmat('../Data/ex8data1.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Xval', 'yval'])

# %%
X=data['X']
Xval=data['Xval']
yval=data['yval']
X.shape
# Out:
# (307, 2)

# %%
plt.scatter(X[:,0],X[:,1],marker='.')
plt.show()

# %% [markdown]
# Looks like some obvious anomalies. Let's see if we can detect them.

# %%
mu = X.mean(0)
sigma2 = X.std(0)**2

# %%
def gaussian(X,mu,sigma2):
    return np.exp(-(X-mu)**2/(2*sigma2))

# %%
p = np.prod(gaussian(X,mu,sigma2),axis=1)

# %%
edge = 1
x1,x2 = np.meshgrid(np.linspace(X[:,0].min()-edge,X[:,0].max()+edge,100),np.linspace(X[:,1].min()-edge,X[:,1].max()+edge,100))
prob_map = np.prod(gaussian(np.c_[x1.ravel(),x2.ravel()],mu,sigma2),axis=1).reshape(100,100)

# %%
plt.figure(figsize=[10,8])
plt.contourf(x1,x2,prob_map,levels=[.01, .1, .5, .9, 1], cmap=plt.get_cmap('inferno'))
plt.colorbar()
plt.scatter(X[:,0],X[:,1],marker='.')
plt.title('Probability Distribution')
plt.show()

# %% [markdown]
# Just from this image, it seems pretty safe to set epsilon to be 0.01, but let's see what sort of procedure the instructions walk us through. However, this set of data isn't *supposed* to have anomalies, as they're supposed to be in the validation data.

# %%
pval = np.prod(gaussian(Xval,mu,sigma2),axis=1)

# %%
granularity = 6
eps_list = [10**(i/granularity) for i in range(-5*granularity,-2*granularity)]
fScoreList = []
for ie, eps in enumerate(eps_list):
    yGuess = pval<eps
    precision = sum(yGuess&yval.ravel())/sum(yGuess)
    recall = sum(yGuess&yval.ravel())/np.sum(yval)
    fScoreList.append(2*precision*recall/(precision+recall))

# %%
plt.plot(eps_list,fScoreList)
plt.xscale('log')
plt.xlabel('epsilon')
plt.ylabel('F-score')
plt.show()

# %%
cell_text = [[f'{eps:.3}' for eps in eps_list], [f'{fScore:.4}' for fScore in fScoreList]]

fig, ax = plt.subplots(1,1, figsize = [16,2])
ax.axis('tight')
ax.axis('off')
tbl = ax.table(cellText=cell_text, rowLabels=['Epsiolon', 'F-Score'],loc='center')
tbl.scale(1,2)
plt.show()

# %% [markdown]
# I want the smallest epsilon that still captures the data, so from this data set that would be eps = 10**(-11/3) = 2.15e-4. It makes sense that the F-Score value would be so quantized, since there are so few anomalies to detect.

# %%
eps = 10**(-11/3)

# %%
yGuess = pval<eps

# %%
sum(yGuess&yval.ravel())/np.sum(yval)
# Out:
# 0.7777777777777778

# %%
sum(yGuess&yval.ravel())/np.sum(yGuess)
# Out:
# 1.0

# %%
np.sum(yval)
# Out:
# 9

# %% [markdown]
# So I'm failing to find two anomalies, but everything that I label as an anomaly *is* an anomaly. The tolerance for this sort of error is very dependent on the purpose of the project, but for this exercise I was told to maximise F-score and this is the epsilon that does that.

# %%
anom = p<eps
plt.figure(figsize=[10,8])
plt.scatter(X[:,0],X[:,1],marker='.')
plt.scatter(X[anom,0],X[anom,1],s=100,facecolor='none',edgecolor='r')
for ia, a in enumerate(anom):
    if a:
        plt.text(X[ia,0],X[ia,1]+.5,f'p={p[ia]:.3}',horizontalalignment='center')
plt.title('Detected Anomalies')
plt.show()

# %% [markdown]
# ### More complex anomaly data (more features)

# %%
data = loadmat('../Data/ex8data2.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Xval', 'yval'])

# %%
X=data['X']
Xval=data['Xval']
yval=data['yval']
X.shape
# Out:
# (1000, 11)

# %% [markdown]
# The instructions want us to just use the implementation we already had, but instead I'm going to use this set to try a manual multi-dimentional gaussian and see what standard implementations there are. First I need to check how normally distributed are the data.

# %%
fig, ax = plt.subplots(3,4,figsize=[12,9],sharey=True)
ax = ax.ravel()
for i in range(11):
    ax[i].hist(X[:,i],bins=50,density=True)
    ax[i].set_title(f'{i}')
plt.show()

# %% [markdown]
# Yup, no tricks, all data is pretty normal.

# %%
m,n = X.shape
mu = X.mean(axis=0).reshape(1,n)
Sigma = np.sum((X-mu).reshape(m,n,1)@(X-mu).reshape(m,1,n),axis=0)/m
detSig = la.det(Sigma)
invSig = la.inv(Sigma)

# %%
pval = np.diag((detSig*(2*np.pi)**n)**(-1/2)*np.exp((-1/2)*((Xval-mu)@invSig@(Xval-mu).T)))

# %%
fig = plt.figure(figsize=[16,12])

granularity = 10
eps_list = [10**(i/granularity) for i in range(-21*granularity,-20*granularity)]
fScoreList = []
for ie, eps in enumerate(eps_list):
    yGuess = pval<eps
    precision = sum(yGuess&yval.ravel())/sum(yGuess)
    recall = sum(yGuess&yval.ravel())/np.sum(yval)
    fScoreList.append(2*precision*recall/(precision+recall))

cell_text = [[f'{eps:.3}' for eps in eps_list], [f'{fScore:.4}' for fScore in fScoreList]]
ax1 = plt.subplot(815)
ax1.axis('tight')
ax1.axis('off')
tbl = ax1.table(cellText=cell_text, rowLabels=['Epsilon', 'F-Score'],loc='center')
tbl.scale(1,2)

ax2 = plt.subplot(222)
ax2.plot(eps_list,fScoreList)
ax2.set_xscale('log')
ax2.set_xlabel('epsilon')
ax2.set_ylabel('F-score')
ax2.set_title('Zoomed In')


granularity = 3
eps_list = [10**(i/granularity) for i in range(-25*granularity,-15*granularity)]
fScoreList = []
for ie, eps in enumerate(eps_list):
    yGuess = pval<eps
    precision = sum(yGuess&yval.ravel())/sum(yGuess)
    recall = sum(yGuess&yval.ravel())/np.sum(yval)
    fScoreList.append(2*precision*recall/(precision+recall))

ax3 = plt.subplot(221)
ax3.plot(eps_list,fScoreList)
ax3.set_xscale('log')
ax3.set_xlabel('epsilon')
ax3.set_ylabel('F-score')
ax3.set_title('Zoomed Out')

plt.show()

# %% [markdown]
# The smallest eps that maximizes F-score is 10**-20.8 = 1.58e-21

# %%
eps = 10**-20.8
p = np.diag((detSig*(2*np.pi)**n)**(-1/2)*np.exp((-1/2)*((X-mu)@invSig@(X-mu).T)))
contamination = sum(p<eps)/m
print(f'The data contain {100*contamination:.3}% outliers')
# Out:
# The data contain 0.7% outliers

# %% [markdown]
# It seems there are [various methods for outlier detection](https://scikit-learn.org/stable/modules/outlier_detection.html), but for the sake of redundancy I'll try to implement the sklearn EllipticEnvelope function.

# %%
from sklearn.covariance import EllipticEnvelope

# %%
conList = [.005 + .005*i for i in range(10) ]
fList = []
for con in conList:
    EE = EllipticEnvelope(contamination=con)
    EE.fit(X)
    yGuessEE = (-(EE.predict(Xval)-1)/2)==1
    recall = sum(yGuessEE&yval.ravel())/np.sum(yval)
    precision = sum(yGuessEE&yval.ravel())/sum(yGuessEE)
    fList.append(2*precision*recall/(precision+recall))

plt.figure(figsize=[16,4])
cell_text = [[f'{con:.3}' for con in conList], [f'{fScore:.4}' for fScore in fList]]
ax1 = plt.subplot(211)
ax1.axis('tight')
ax1.axis('off')
tbl = ax1.table(cellText=cell_text, rowLabels=['Contamination', 'F-Score'],loc='center')
tbl.scale(1,2)

conList = [.035 + .002*i for i in range(10)]
fList = []
for con in conList:
    EE = EllipticEnvelope(contamination=con)
    EE.fit(X)
    yGuessEE = (-(EE.predict(Xval)-1)/2)==1
    recall = sum(yGuessEE&yval.ravel())/np.sum(yval)
    precision = sum(yGuessEE&yval.ravel())/sum(yGuessEE)
    fList.append(2*precision*recall/(precision+recall))

cell_text = [[f'{con:.3}' for con in conList], [f'{fScore:.4}' for fScore in fList]]
ax1 = plt.subplot(212)
ax1.axis('tight')
ax1.axis('off')
tbl = ax1.table(cellText=cell_text, rowLabels=['Contamination', 'F-Score'],loc='center')
tbl.scale(1,2)

# %% [markdown]
# So it appears that this method is sensitive to the contamination value AND the F-score isn't as good as my implementation. That probalby means that I usually wouldn't want to use this implementation, and there are many reasons.
# 1. It's not as good as the manual implementation...
#     * and the manual implementation is pretty easy.
# 2. There are 3 other outlier detection schemes in sklearn...
#     * and they all seem to work better on the toy data set.
#
# In the end, from personal experience, I know that outlier detection is very hard, so I can't fault this too much. If I ever had to tackle the problem professionally, I'd have to read up on the most up-to-date methodologies.

# %% [markdown]
# # Recommender Systems
# EDIT: After working with this problem for quite a while, I've come to the conclusion that this is probably the problem most dependent on the user following along with the Matlab code. The pdf instructions fail to mention numerous important things. The provided X and Theta matrices are already mostly trained. The user was meant to initialize their own for training. Additionally, there are some numbers provided for confirmation, but it's not made clear that the provided matrices were intended to be truncated to achieve these results, so I spent most of the time thinking I did something wrong despite the many times I went over my equations.
#
# It seems there is no sklearn implementation of collaborative filtering, but I can at least try to figure out how to do function minimization the standard way. And I'll also try a manual implementation to confirm the results.
#
# First, let's see what I'm working with.

# %%
movies = loadmat('../Data/ex8_movies.mat')
movies.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Y', 'R'])

# %%
Y = movies['Y'] #ratings, indexed by (movie, user)
R = movies['R'] #has user seen movie
print(f'Y shape is {Y.shape} and R shape is the same.')
# Out:
# Y shape is (1682, 943) and R shape is the same.

# %%
movieParams = loadmat('../Data/ex8_movieParams.mat')
movieParams.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Theta', 'num_users', 'num_movies', 'num_features'])

# %%
X = movieParams['X'] # movie feature vector
Theta = movieParams['Theta'] #user feature vector
print(f'X shape is {X.shape} and Theta shape is {Theta.shape}.')
# Out:
# X shape is (1682, 10) and Theta shape is (943, 10).

# %%
nm, nu = R.shape #num movies, num users
nf = X.shape[1] #num features (a free variable)
print(f'Numer of users: {nu}\nNumber of movies: {nm}\nNumber of features: {nf}')
# Out:
# Numer of users: 943
# Number of movies: 1682
# Number of features: 10

# %%
def costFunction(X,Y,Theta,R):
    return np.sum(R*(X@Theta.T-Y)**2)/2

# %%
costFunction(X[:5,:3],Y[:5,:4],Theta[:4,:3],R[:5,:4])
# Out:
# 22.224603725685675

# %% [markdown]
# This matches with the pdf document, but I had to go into the matlab code to find the indices of the matrices that were used.

# %%
def costFunctionLamda(X,Y,Theta,R,lamda):
    return np.sum(R*(X@Theta.T-Y)**2)/2 + (lamda/2)*(np.sum(X**2) + np.sum(Theta**2))

# %%
costFunctionLamda(X[:5,:3],Y[:5,:4],Theta[:4,:3],R[:5,:4],lamda=1.5)
# Out:
# 31.34405624427422

# %% [markdown]
# This also matches with the pdf document, but I had to go into the matlab code to find the value of lambda that was used.
#
# Now onto the minimization. If I want to employ the scipy minimize function I need to get the data into a 1-D shape so that requires a little bit of redefinition of my cost function, but not too much.

# %%
def costFunctionCombo(combo,R,Y,nf,lamda):
    nm, nu = Y.shape
    X = combo[:nm*nf].reshape(nm,nf)
    Theta = combo[nm*nf:].reshape(nu,nf)
    return np.sum(R*(X@Theta.T-Y)**2) + (lamda/2)*(np.sum(X**2)+np.sum(Theta**2))

def costFunctionJacobian(combo,R,Y,nf,lamda):
    nm, nu = Y.shape
    X = combo[:nm*nf].reshape(nm,nf)
    Theta = combo[nm*nf:].reshape(nu,nf)
    gradTheta = (X.T@(R*(X@Theta.T-Y))).T + lamda*Theta
    gradX = R*(X@Theta.T-Y)@Theta + lamda*X
    return np.r_[gradX.ravel(),gradTheta.ravel()]

# %%
combo = np.r_[X.ravel(),Theta.ravel()]

# %% [markdown]
# While I'm pretty confident of my Jacobian, I want to double check it.

# %%
from scipy.optimize import check_grad

# %%
check_grad(costFunctionCombo,costFunctionJacobian,combo,R,Y,nf,lamda)
# Out:
# 473.8824640906842

# %%
np.sum(costFunctionJacobian(combo,R,Y,nf,lamda))
# Out:
# -13724.649237681475

# %% [markdown]
# Turns out it's a relatively small error, especially considering check grad just uses a forward difference to estimate. So an error as high as a couple percent with this many dimensions isn't too surprising.

# %%
from scipy.optimize import minimize

# %%
lamda=1

# %% [markdown]
# I tried a few different methods among the ones that required a Jacobian (since I had that, I wanted to use it) and the default, BFGS used too much memory. Newton-CG was really slow. In the end, I stuck with CG even though I had to repeat it a few times to find a true minimum.

# %%
res = minimize(costFunctionCombo,combo,jac=costFunctionJacobian,args=(R,Y,nf,lamda),options={'disp':True},method='CG')
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 54594.098655
#          Iterations: 70
#          Function evaluations: 248
#          Gradient evaluations: 237

# %%
for _ in range(10):
    res = minimize(costFunctionCombo,res.x,jac=costFunctionJacobian,args=(R,Y,nf,lamda),options={'disp':True},method='CG')
    if res['nit'] == 0:
        break
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 54001.461854
#          Iterations: 148
#          Function evaluations: 458
#          Gradient evaluations: 447
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 54000.735779
#          Iterations: 4
#          Function evaluations: 62
#          Gradient evaluations: 51
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 54000.728488
#          Iterations: 1
#          Function evaluations: 47
#          Gradient evaluations: 35
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 54000.728488
#          Iterations: 0
#          Function evaluations: 52
#          Gradient evaluations: 41

# %%
newX = res.x[:nm*nf].reshape(nm,nf)
newTheta = res.x[nm*nf:].reshape(nu,nf)

# %%
fig, ax = plt.subplots(1,2,sharey=True,figsize=[16,8])
yGuess = (R*(X@Theta.T)).ravel()
ax[0].hist(yGuess[np.nonzero(yGuess)],density=True,bins=range(7),label='Guess',alpha=.8)
tmpY = Y.ravel()
ax[0].hist(tmpY[np.nonzero(tmpY)],density=True,bins=range(7),label='Actual',alpha=.8)
ax[0].legend()
ax[0].set_title('Initial Guess')

yGuess = (R*(newX@newTheta.T)).ravel()
ax[1].hist(yGuess[np.nonzero(yGuess)],density=True,bins=range(7),label='Guess',alpha=.8)
ax[1].hist(tmpY[np.nonzero(tmpY)],density=True,bins=range(7),label='Actual',alpha=.8)
ax[1].legend()
ax[1].set_title('Trained Guess')

plt.show()

# %% [markdown]
# So the training didn't do much. Turns out it was already pretty well trained. It was maybe even *fully* trained, but with a different, higher lambda.
#
# Now I want to see if a manual gradient descent algorithm does any better, just to make sure that the minimize function is doing what I think it should be doing.

# %%
def gradientDescent(combo,R,Y,nf,lamda,alpha=.01,iterations=100):
    jList = []
    newCombo = np.copy(combo)
    nm, nu = Y.shape
    for _ in range(iterations):
        gradJ = costFunctionJacobian(newCombo,R,Y,nf,lamda)
        newCombo -= alpha*gradJ
        jList.append(costFunctionCombo(newCombo,R,Y,nf,lamda))
    return newCombo, jList

# %%
newCombo,jList = gradientDescent(combo,R,Y,nf,lamda=1,alpha=.0005,iterations=1000)

# %%
plt.plot(jList)
plt.ylim([min(jList), max(jList)])
plt.ylabel('Error')
plt.xlabel('Iterations')
plt.show()

# %% [markdown]
# Looks like it's going to approach that same 54,000 error as the CG algorithm, albeit much more slowly.
#
# The instructions next asks you add some of your own ratings and see what gets recommended to you. This requires importing a movie list and generating some ratings. Most important for the analysis is it requires training the algoritm with a normalized Y variable, keeping track of the mean rating for each movie. Because when a new user comes along if they haven't seen any movies then all the algorith, as it stands, would predict a zero rating for all movies. It's more realistic to predict that a new user would simply rate every movie as its average rating and adjust later when they have some ratings to provide.
#
# Doing this with this toy data set doesn't sound very interesting to me. Video recommendation constitutes some very valuable companies, so even toying with the problem as an individual doesn't sound appealing to me. I'll try to implement something like this in a different project, instead. In the end, it's just another application of function minimization, which was one of the first topics covered in the course. It is the idea of collaborative filtering which makes this project unique.
#
# I think this is a good capstone to this course, because the differnce between this code and the code from my first exercise can directly demonstrate my progress with both python and machine learning.
#
# It's been a very good course. I'm excited to see what the videso of the last two weeks demonstrate, but I'm also glad to be done with the exercises. They really tested me and taught me a lot.
